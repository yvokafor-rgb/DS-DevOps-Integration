# %% [markdown]
# # Data Exploration
#
# This notebook explores the raw dataset to understand its structure, distributions, and potential issues.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# Set style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# %%
# Load raw data
data_path = Path("../data/raw")
# TODO: Update with actual filename
# df = pd.read_csv(data_path / "your_dataset.csv")

# Basic info
# print(df.info())
# print(df.describe())
# print(df.head())
