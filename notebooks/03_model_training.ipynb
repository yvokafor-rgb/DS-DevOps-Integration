# %% [markdown]
# # Model Training
#
# This notebook trains individual models (Logistic Regression and Random Forest).

# %%
import sys
from pathlib import Path

sys.path.append(str(Path("../src")))

from train_logreg import train_logistic_regression
from train_rf import train_random_forest
from utils import load_data

# Load processed data
# df = load_data(Path("../data/processed/processed_data.csv"))
# target_col = df.columns[-1]
# y = df[target_col]
# X = df.drop(columns=[target_col])

# Train models
# logreg_model = train_logistic_regression(X, y)
# rf_model = train_random_forest(X, y)
