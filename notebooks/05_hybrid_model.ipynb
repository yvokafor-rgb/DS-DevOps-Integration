# %% [markdown]
# # Hybrid Model
#
# This notebook trains and evaluates the hybrid ensemble model.

# %%
import sys
from pathlib import Path

sys.path.append(str(Path("../src")))

from train_hybrid import train_hybrid_model
from utils import load_data

# Load processed data
# df = load_data(Path("../data/processed/processed_data.csv"))
# target_col = df.columns[-1]
# y = df[target_col]
# X = df.drop(columns=[target_col])

# Train hybrid model
# hybrid_model = train_hybrid_model(X, y, weights=(0.5, 0.5))
