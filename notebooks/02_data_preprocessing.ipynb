# %% [markdown]
# # Data Preprocessing
#
# This notebook handles data cleaning, outlier removal, and SMOTE balancing.

# %%
import sys
from pathlib import Path

sys.path.append(str(Path("../src")))

from data_prep import preprocess_data

# Run preprocessing pipeline
# X, y = preprocess_data(apply_smote_flag=True)
