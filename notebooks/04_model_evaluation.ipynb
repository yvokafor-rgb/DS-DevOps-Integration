# %% [markdown]
# # Model Evaluation
#
# This notebook evaluates trained models and compares their performance.

# %%
import sys
import pickle
from pathlib import Path

sys.path.append(str(Path("../src")))

from evaluate import evaluate_model

# Load models and evaluate
# with open(Path("../models/logreg/logreg_model.pkl"), "rb") as f:
#     logreg_model = pickle.load(f)

# Evaluate on test set
# y_pred = logreg_model.predict(X_test)
# metrics = evaluate_model(y_test, y_pred, model_name="Logistic Regression")
